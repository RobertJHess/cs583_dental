# %% [markdown]
# # Run ONNX export

# %%
#get a model called best onnx under the train 14 weights
from ultralytics import YOLO

model = YOLO("runs/segment/train14/weights/best.pt")
model.export(format="onnx")
# Out:
# Ultralytics 8.3.230  Python-3.10.6 torch-2.1.0+cpu CPU (11th Gen Intel Core i7-1165G7 @ 2.80GHz)
# YOLOv8s-seg summary (fused): 85 layers, 11,788,888 parameters, 0 gradients, 40.0 GFLOPs
#
# PyTorch: starting from 'runs\segment\train14\weights\best.pt' with input shape (1, 3, 512, 512) BCHW and output shape(s) ((1, 60, 5376), (1, 32, 128, 128)) (22.7 MB)
#
# ONNX: starting export with onnx 1.19.1 opset 17...
# ONNX: slimming with onnxslim 0.1.75...
# ONNX: export success  1.8s, saved as 'runs\segment\train14\weights\best.onnx' (45.2 MB)
#
# Export complete (2.5s)
# Results saved to C:\Users\jinsu\Downloads\Dental Project final\runs\segment\train14\weights
# Predict:         yolo predict task=segment model=runs\segment\train14\weights\best.onnx imgsz=512
# Validate:        yolo val task=segment model=runs\segment\train14\weights\best.onnx imgsz=512 data=data/opg/data.yaml
# Visualize:       https://netron.app
# 'runs\\segment\\train14\\weights\\best.onnx'
