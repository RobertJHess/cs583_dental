# %% [markdown]
# # Run inference on test images

# %%
from ultralytics import YOLO

model = YOLO("runs/segment/train14/weights/best.pt")

results = model.predict(
    source="data/opg/test/images",
    save=True,
    imgsz=512,
    conf=0.25
)
# Out:
# image 1/17 c:\Users\jinsu\Downloads\Dental Project final\data\opg\test\images\Achuthan_-_20221125_958_jpg.rf.a525462fca663d8086e24a4ef5c77665.jpg: 512x512 2 CONDYLEs, 2 CROWNs, 2 CROWN AND BRIDGEs, 1 HARD PALATE, 1 IMPLANT, 2 INFERIOR ALVEOLAR NERVE CANALs, 1 INFERIOR BORDER OF MANDIBLE, 3 ROOT CANAL TREATED TOOTHs, 2 SHORTENED RCTs, 535.7ms
# image 2/17 c:\Users\jinsu\Downloads\Dental Project final\data\opg\test\images\Adithya-Mahadev_-_20230515_3847_jpg.rf.8b3be17e6ca5cde3d59ff68daa879e1e.jpg: 512x512 1 CONDYLE, 2 ERUPTING TOOTHs, 2 HARD PALATEs, 2 INFERIOR ALVEOLAR NERVE CANALs, 1 INFERIOR BORDER OF MANDIBLE, 269.3ms
# image 3/17 c:\Users\jinsu\Downloads\Dental Project final\data\opg\test\images\Afna-Raseef_-_20230524_4009_jpg.rf.b9b24aae017dfa042075524fe70dc574.jpg: 512x512 2 CONDYLEs, 1 HARD PALATE, 2 INFERIOR ALVEOLAR NERVE CANALs, 1 INFERIOR BORDER OF MANDIBLE, 318.2ms
# ...
